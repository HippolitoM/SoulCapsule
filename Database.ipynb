# %%
import pandas as pd
import numpy as np

# %%
produits=["espresso","americano","double_espresso"]
carac_prod={} #prix, emplacement, calories
carac_prod['espresso']=[1,"haut",100]
carac_prod['americano']=[2,"milieu",350]
carac_prod['double_espresso']=[1.7,"bas",200]

taille=10000

# %%
ventes_matin={}
ventes_matin['produit']=[produits[np.random.randint(0,3)] for i in range (1,taille)]
def indications(nom, pos):
    ventes_matin[nom]=[carac_prod[ventes_matin['produit'][i]][pos] for i in range (len(ventes_matin['produit']))]

indications('prix',0)
indications('emplacement',1)
indications('calories',2)

ventes_matin['affluence']=[int(np.random.exponential(5))+1 for i in range (1,taille)]

# %%
db=pd.DataFrame(ventes_matin)
db.head()
# Out:
#            produit  prix emplacement  calories  affluence
# 0  double_espresso   1.7         bas       200          4
# 1  double_espresso   1.7         bas       200          4
# 2        americano   2.0      milieu       350         11
# 3  double_espresso   1.7         bas       200          1
# 4        americano   2.0      milieu       350          6

# %%
db['produit'].value_counts()
dba=db.loc[db.produit=="americano"]
dba['affluence'].mean()
# Out:
#               produit  prix emplacement  calories  affluence
# 0     double_espresso   1.7         bas       200          4
# 1     double_espresso   1.7         bas       200          4
# 2           americano   2.0      milieu       350         11
# 3     double_espresso   1.7         bas       200          1
# 4           americano   2.0      milieu       350          6
# 5           americano   2.0      milieu       350          2
# 6     double_espresso   1.7         bas       200          3
# 7            espresso   1.0        haut       100          5
# 8            espresso   1.0        haut       100          2
# 9           americano   2.0      milieu       350          5
# 10          americano   2.0      milieu       350          7
# 11          americano   2.0      milieu       350         11
# 12          americano   2.0      milieu       350          3
# 13          americano   2.0      milieu       350          3
# 14          americano   2.0      milieu       350          4
# 15           espresso   1.0        haut       100          1
# 16           espresso   1.0        haut       100          7
# 17           espresso   1.0        haut       100          4
# 18          americano   2.0      milieu       350          5
# 19           espresso   1.0        haut       100          8
# 20          americano   2.0      milieu       350          2
# 21          americano   2.0      milieu       350          9
# 22          americano   2.0      milieu       350          2
# 23    double_espresso   1.7         bas       200          1
# 24          americano   2.0      milieu       350          9
# 25           espresso   1.0        haut       100          4
# 26          americano   2.0      milieu       350          5
# 27           espresso   1.0        haut       100          3
# 28          americano   2.0      milieu       350          6
# 29           espresso   1.0        haut       100          1
# ...               ...   ...         ...       ...        ...
# 9969         espresso   1.0        haut       100          8
# 9970  double_espresso   1.7         bas       200          1
# 9971  double_espresso   1.7         bas       200         17
# 9972        americano   2.0      milieu       350          1
# 9973        americano   2.0      milieu       350          7
# 9974         espresso   1.0        haut       100          9
# 9975  double_espresso   1.7         bas       200         10
# 9976        americano   2.0      milieu       350          4
# 9977        americano   2.0      milieu       350          6
# 9978         espresso   1.0        haut       100         10
# 9979         espresso   1.0        haut       100          6
# 9980         espresso   1.0        haut       100          4
# 9981        americano   2.0      milieu       350          3
# 9982  double_espresso   1.7         bas       200          5
# 9983         espresso   1.0        haut       100          8
# 9984        americano   2.0      milieu       350         14
# 9985         espresso   1.0        haut       100         10
# 9986        americano   2.0      milieu       350          6
# 9987         espresso   1.0        haut       100          1
# 9988         espresso   1.0        haut       100          2
# 9989        americano   2.0      milieu       350         15
# 9990  double_espresso   1.7         bas       200          4
# 9991  double_espresso   1.7         bas       200         12
# 9992         espresso   1.0        haut       100          2
# 9993  double_espresso   1.7         bas       200         10
# 9994        americano   2.0      milieu       350          3
# 9995  double_espresso   1.7         bas       200          1
# 9996        americano   2.0      milieu       350          1
# 9997         espresso   1.0        haut       100          1
# 9998  double_espresso   1.7         bas       200          5
#
# [9999 rows x 5 columns]
